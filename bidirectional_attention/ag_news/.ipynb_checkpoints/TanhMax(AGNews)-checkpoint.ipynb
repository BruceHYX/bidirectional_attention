# %% [markdown]
# ### Attention of TanhMax(AGNews)

# %%
import pandas as pd
import torch.utils.data as Data
import torch.optim as optim
from torch.autograd import Variable
import torch
import pickle
from torch import optim
import torch.nn as nn
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
filename = 'data/local_dict.pkl'
path = filename
dict_file = open(path, 'rb')

vocab  = pickle.load(dict_file)[0]
print('length of vocabulary: ',len(vocab))
dict_file.close()

filename = "data/Train.csv"
Train = pd.read_csv(filename)
# Out:
# length of vocabulary:  16174

# %%
vocab_size = 8000
text_length = 30
batch_size = 100
epoch_num = 100

word2idx = {'[PAD]':0}
for i, w in enumerate(vocab[:vocab_size]):
    word2idx[w] = i + 1
idx2word = {i: w for i, w in enumerate(word2idx)}

doc_list = Train['text'].to_list()
labels = Train['label'].astype('int').to_list()

# %%
from model import make_data
data = make_data(doc_list,word2idx,text_length)

# %%
len(data),len(labels)
# Out:
# (60000, 60000)

# %%
from model import MyDataSet

batch = Variable(torch.LongTensor(data))
labels = Variable(torch.LongTensor(labels))
loader = Data.DataLoader(MyDataSet(batch,labels), batch_size, True)

# %%
from model import SelfAttnClassifier

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

loss_function = nn.BCELoss()
model = SelfAttnClassifier(vocab_size+1, 200, 100, 1, scale=5.0,activation='TanhMax')
optimizer = torch.optim.Adadelta(model.parameters(), lr=0.05)

use_gpu = torch.cuda.is_available()

if(use_gpu):
    model = model.cuda()
    loss_function = loss_function.cuda()

# %%
model.train()
for epoch in tqdm(range(100)):
    for input_ids, label in loader:
        model.zero_grad()
        preds = model(input_ids.cuda())
        loss = loss_function(preds.squeeze(), label.cuda().float()) * 100
        loss.backward(retain_graph=True)
        optimizer.step()
        input_ids.cpu()
        label.cpu()
# Out:
# 100%|██████████| 100/100 [09:31<00:00,  5.71s/it]

# %%
from model import plot_cm_matrix
plot_cm_matrix(model,batch,labels,save_url='graph/metric/TanhMaxTrainAcc.png')
# Out:
# accuracy:92.382%

# %% [markdown]
# ### test accuracy

# %%
filename = "data/Test.csv"
Test = pd.read_csv(filename)

doc_list = Test['text'].to_list()
test_labels = Test['label'].astype('int').to_list()
    
test_data = make_data(doc_list,word2idx,text_length)
len(test_data),len(test_labels)
# Out:
# (3800, 3800)

# %%
test_batch = Variable(torch.LongTensor(test_data))
test_labels = Variable(torch.LongTensor(test_labels))
plot_cm_matrix(model,test_batch,test_labels,save_url='graph/metric/picture6.png')
# Out:
# accuracy:90.526%

# %% [markdown]
# ### Save Model

# %%
## 保存
torch.save(model.state_dict(), 'model/TanhMaxParameter.pkl')
torch.save(model, 'model/TanhMaxModel.pkl')

## 加载
#model = SelfAttnClassifier(vocab_size+1, 30, 10, 1, scale=5.0,score_function='dot',activation='SoftMax')
#model.load_state_dict(torch.load('model/SoftmaxParameter.pkl'))

# 加载
#model = torch.load('model/SoftmaxModel.pkl')

# %% [markdown]
# ### Select Tokens

# %%
from model import SelectTokens
Pos,Neg,Neu = SelectTokens(data,labels,word2idx)

# %% [markdown]
# ### Visualization

# %%
from model import compute_coefficients
pos_index,pos_score,pos_weight,neg_index,neg_score,neg_weight,neutral_index,neutral_score,neutral_weight = compute_coefficients(model,batch,Pos,Neg,Neu,word2idx)

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_score, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_score, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_score, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Score')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture4.png')
print('Pos Mean:',np.mean(pos_score),'Pos Std:',np.std(pos_score))
print('Neg Mean:',np.mean(neg_score),'Neg Std:',np.std(neg_score))
print('Neu Mean:',np.mean(neutral_score),'Neu Std:',np.std(neutral_score))
# Out:
# Pos Mean: 3.565529080541575 Pos Std: 1.0129967322813727
# Neg Mean: -2.2814586130736116 Neg Std: 1.0417633356726466
# Neu Mean: 1.446898642807211 Neu Std: 1.244732265297935

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_weight, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_weight, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_weight, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Weight')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture5.png')
print('Pos Mean:',np.mean(pos_weight),'Pos Std:',np.std(pos_weight))
print('Neg Mean:',np.mean(neg_weight),'Neg Std:',np.std(neg_weight))
print('Neu Mean:',np.mean(neutral_weight),'Neu Std:',np.std(neutral_weight))
# Out:
# Pos Mean: 0.17722099011308423 Pos Std: 0.1357088717599675
# Neg Mean: -0.08650465556043188 Neg Std: 0.09270520754662491
# Neu Mean: 0.04439430816192677 Neu Std: 0.0644404643370435

# %% [markdown]
# ### Exp1 -- Gradient Importance

# %%
from model import GradientImportance
GradientImportance(model,test_batch,test_labels,'TanhMax')
# Out:
# 3800it [00:09, 413.45it/s]
# Both label
# 	p-value < 0.05: 3797  ratio: 0.9992105263157894
# 	p-value < 0.01: 3784  ratio: 0.9957894736842106
# 	Both-Mean: 0.6935074339337134 Std: 0.11952660386633783
#
# Pos
# 	p-value < 0.05: 1897  ratio: 0.998421052631579
# 	p-value < 0.01: 1888  ratio: 0.9936842105263158
# 	Pos-Mean: 0.6503129155710023 Std: 0.12470314849124423
#
# Neg
# 	p-value < 0.05: 1900  ratio: 1.0
# 	p-value < 0.01: 1896  ratio: 0.9978947368421053
# 	Neg-Mean: 0.7367019522964241 Std: 0.09638884783437573

# %% [markdown]
# ### Exp2--Feature Erasure

# %%
from model import FeatureErasure
FeatureErasure(model,test_batch,test_labels,'TanhMax')
# Out:
# 3800it [00:50, 74.86it/s]
# Both label
# 	p-value < 0.05: 3797  ratio: 0.9992105263157894
# 	p-value < 0.01: 3791  ratio: 0.9976315789473684
# 	total num: 3800  mean: 0.8325928328641459  std: 0.10533226804882131
# Pos
# 	p-value < 0.05: 1899  ratio: 0.9994736842105263
# 	p-value < 0.01: 1894  ratio: 0.9968421052631579
# 	total num: 1900  mean: 0.8365549587567535  std: 0.10590945357720888
# Neg
# 	p-value < 0.05: 1898  ratio: 0.9989473684210526
# 	p-value < 0.01: 1897  ratio: 0.998421052631579
# 	total num: 1900  mean: 0.8286307069715385  std: 0.1046019318388374

# %% [markdown]
# ### Exp3--Feature Erasure ABS

# %%
from model import FeatureErasureABS
FeatureErasureABS(model,test_batch,test_labels,'TanhMax')
# Out:
# 3800it [00:51, 73.42it/s]
# Both label
# 	p-value < 0.05: 3800  ratio: 1.0
# 	p-value < 0.01: 3799  ratio: 0.9997368421052631
# 	total num: 3800  mean: 0.8940431176476894  std: 0.06334560641030393
# Pos
# 	p-value < 0.05: 1900  ratio: 1.0
# 	p-value < 0.01: 1900  ratio: 1.0
# 	total num: 1900  mean: 0.898626286661492  std: 0.06393008499156334
# Neg
# 	p-value < 0.05: 1900  ratio: 1.0
# 	p-value < 0.01: 1899  ratio: 0.9994736842105263
# 	total num: 1900  mean: 0.8894599486338864  std: 0.0624200693650015

# %% [markdown]
# ### Exp4--Attention Permutation

# %%
from model import AttnPermutation
AttnPermutation(model,test_batch,test_labels,'TanhMax')
# Out:
# 3800it [03:37, 17.48it/s]
# Both label
# 	total num: 3800  mean: 0.15135813  std: 0.122029096
# Pos
# 	total num: 1900  mean: 0.118305035  std: 0.10223255
# Neg
# 	total num: 1900  mean: 0.1844112  std: 0.13094157
#                   median                                                    \
#                    count      mean       std       min       25%       50%
# label group
# Neg   [0.,0.25)   1657.0  0.181311  0.132265  0.000611  0.069193  0.165265
#       [0.25,0.5)   172.0  0.209136  0.120624  0.016279  0.113222  0.205494
#       [0.5,0.75)    62.0  0.208639  0.113774  0.007085  0.109290  0.234837
#       [0.75,1.0)     9.0  0.115685  0.126914  0.028026  0.038310  0.054001
# Pos   [0.,0.25)    381.0  0.146279  0.093210  0.007907  0.080978  0.125682
#       [0.25,0.5)  1016.0  0.091674  0.077058  0.006622  0.035864  0.065742
#       [0.5,0.75)   424.0  0.143634  0.126102  0.003407  0.035425  0.092934
#       [0.75,1.0)    79.0  0.189941  0.164347  0.007181  0.027784  0.125521
#
#
#                        75%       max
# label group
# Neg   [0.,0.25)   0.266728  0.573228
#       [0.25,0.5)  0.269159  0.591482
#       [0.5,0.75)  0.297337  0.440456
#       [0.75,1.0)  0.116749  0.381434
# Pos   [0.,0.25)   0.198334  0.573030
#       [0.25,0.5)  0.122012  0.432861
#       [0.5,0.75)  0.237572  0.443726
#       [0.75,1.0)  0.348984  0.452112

# %% [markdown]
# ### Exp5--Attention Randomization

# %%
from model import AttnRandom
AttnRandom(model,test_batch,test_labels,'TanhMax')
# Out:
# 3800it [03:12, 19.75it/s]
# Both label
# 	total num: 3800  mean: 0.4605355  std: 0.2888131
# Pos
# 	total num: 1900  mean: 0.4362065  std: 0.2790127
# Neg
# 	total num: 1900  mean: 0.48486456  std: 0.29630077
#                   median                                                    \
#                    count      mean       std       min       25%       50%
# label group
# Neg   [0.,0.25)    869.0  0.469379  0.281323  0.004043  0.236426  0.433850
#       [0.25,0.5)   686.0  0.487820  0.305632  0.005595  0.204118  0.466897
#       [0.5,0.75)   130.0  0.491924  0.285511  0.013153  0.245528  0.475806
#       [0.75,1.0)   215.0  0.533756  0.326953  0.001390  0.206933  0.562016
# Pos   [0.,0.25)    366.0  0.437334  0.233275  0.009507  0.261669  0.425642
#       [0.25,0.5)  1026.0  0.440525  0.287069  0.002810  0.180869  0.421808
#       [0.5,0.75)   427.0  0.436709  0.287870  0.005087  0.181663  0.420626
#       [0.75,1.0)    81.0  0.373758  0.315087  0.012237  0.089401  0.254836
#
#
#                        75%       max
# label group
# Neg   [0.,0.25)   0.716585  0.992871
#       [0.25,0.5)  0.774646  0.995526
#       [0.5,0.75)  0.743593  0.991589
#       [0.75,1.0)  0.842115  0.998834
# Pos   [0.,0.25)   0.604918  0.996165
#       [0.25,0.5)  0.688155  0.994132
#       [0.5,0.75)  0.687921  0.990414
#       [0.75,1.0)  0.591687  0.979543

# %% [markdown]
# ### check selected tokens

# %%
pos_df = pd.DataFrame(zip(pos_index,pos_score),columns=['index','value'])
pos_top_index = pos_df.sort_values(by='value',ascending=False)['index'].values[:100]
pos_top_words = []
for item in pos_top_index:
    pos_top_words.append(idx2word[item])
print(pos_top_words)
print(len(pos_df))
# Out:
# ['snow', 'com', 'barrel', 'commerce', 'martha', 'bankrupt', 'disney', 'consumers', 'inc', 'reliance', 'entertainment', 'managing', 'walt', 'lynch', 'crude', 'exploration', 'ford', 'diesel', 'higher', 'benchmark', 'corporate', 'stock', 'charlie', 'invest', 'freddie', 'average', 'venture', 'giant', 'insurance', 'auto', 'frank', 'marketing', 'stewart', 'lows', 'highs', 'o', 'franklin', 'studios', 'phones', 'versus', 'pack', 'fields', 'warner', 'value', 'g', 'universal', 'diva', 'credit', 'quality', 'hybrid', 'fare', 'fun', 'business', 'bond', 'store', 'practices', 'unexpectedly', 'claude', 'p', 'flows', 'watts', 'c', 'bought', 'makers', 'lifestyle', 'typical', 'costly', 'fueled', 'maker', 'flat', 'market', 'co', 'apple', 'balance', 'volume', 'chapter', 'plus', 'roaring', 'edged', 'thin', 'tech', 'rating', 'combined', 'mart', 'spike', 'hang', 'chase', 'chain', 'levy', 'frequent', 'versions', 'bit', 'trend', 'standard', 'barrels', 'competition', 'employment', 'blockbuster', 'francisco', 'holiday']
# 584

# %%
neg_df = pd.DataFrame(zip(neg_index,neg_score),columns=['index','value'])
neg_top_index = neg_df.sort_values(by='value',ascending=True)['index'].values[:100]
neg_top_words = []
for item in neg_top_index:
    neg_top_words.append(idx2word[item])
print(neg_top_words)
print(len(neg_df))
# Out:
# ['palestinian', 'hostage', 'nuclear', 'explosions', 'soldiers', 'israeli', 'jewish', 'killing', 'killed', 'religious', 'iran', 'submarine', 'crimes', 'survivors', 'al', 'filmmaker', 'armed', 'intelligence', 'refugees', 'arms', 'cup', 'offensive', 'murder', 'jordan', 'military', 'warming', 'israel', 'freedom', 'terrorism', 'climate', 'occupied', 'dialogue', 'peace', 'riot', 'invasion', 'bomb', 'assassination', 'buried', 'journalist', 'ballistic', 'pinochet', 'gay', 'death', 'adrian', 'photographer', 'alert', 'jacques', 'plot', 'pro', 'grave', 'forces', 'captured', 'girl', 'violent', 'league', 'siege', 'cia', 'ethnic', 'rain', 'torn', 'deadly', 'violence', 'prime', 'winds', 'liberation', 'cricket', 'secretary', 'turkey', 'kim', 'press', 'terror', 'kill', 'festival', 'liberal', 'torture', 'train', 'reconstruction', 'rebel', 'witnesses', 'traces', 'father', 'captain', 'ballot', 'ivory', 'princess', 'spy', 'party', 'missing', 'blair', 'suspected', 'mission', 'abuse', 'remote', 'homosexuality', 'explosion', 'suicide', 'girls', 'terrorists', 'smoke', 'tons']
# 601

# %%
neu_df = pd.DataFrame(zip(neutral_index,neutral_score),columns=['index','value'])
neu_top_index1 = neu_df.sort_values(by='value',ascending=True)['index'].values[:50]
neu_top_index2 = neu_df.sort_values(by='value',ascending=False)['index'].values[:50]
neu_top_words = []
for item in neu_top_index1:
    neu_top_words.append(idx2word[item])
for item in neu_top_index2:
    neu_top_words.append(idx2word[item])
print(neu_top_words)
print(len(neu_df))
# Out:
# ['borders', 'developments', 'reaction', 'consider', 'developed', 'depressed', 'sometimes', 'games', 'williams', 'quickly', 'beauty', 'drew', 'forest', 'displays', 'kong', 'film', 'machine', 'beating', 'davies', 'limits', 'eyed', 'catch', 'display', 'changing', 'mason', 'space', 'contribution', 'handle', 'jay', 'establish', 'talk', 'comfortable', 'include', 'expiration', 'skin', 'shadow', 'eighth', 'oscar', 'challenges', 'becomes', 'able', 'stadium', 'feisty', 'hat', 'cinema', 'mary', 'story', 'folk', 'minus', 'norwegian', 'tangled', 'convincing', 'lengthy', 'fires', 'tunnel', 'resident', 'ray', 'dedicated', 'knew', 'exact', 'skies', 'reluctant', 'listen', 'wake', 'anyway', 'vulnerable', 'stick', 'discussion', 'dust', 'counterparts', 'diverse', 'politically', 'resist', 'scathing', 'afraid', 'stone', 'usual', 'deserves', 'shock', 'trash', 'seemingly', 'mike', 'daniel', 'ron', 'loaded', 'chosen', 'quiet', 'college', 'ones', 'complex', 'individuals', 'conscious', 'quietly', 'dynamite', 'payoff', 'shared', 'lukewarm', 'brimming', 'talking', 'haunting']
# 1149
