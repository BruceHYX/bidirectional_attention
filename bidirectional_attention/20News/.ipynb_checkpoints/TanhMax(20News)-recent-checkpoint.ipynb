# %% [markdown]
# ### Attention of TanhMax(20News)

# %%
import pandas as pd
import torch.utils.data as Data
import torch.optim as optim
from torch.autograd import Variable
import torch
import pickle
from torch import optim
import torch.nn as nn
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
filename = 'data/local_dict.pkl'
path = filename
dict_file = open(path, 'rb')

vocab  = pickle.load(dict_file)[0]
print('length of vocabulary: ',len(vocab))
dict_file.close()

filename = "data/Train.csv"
Train = pd.read_csv(filename)
# Out:
# length of vocabulary:  16174

# %%
vocab_size = 8000
text_length = 30
batch_size = 100
epoch_num = 100

word2idx = {'[PAD]':0}
for i, w in enumerate(vocab[:vocab_size]):
    word2idx[w] = i + 1
idx2word = {i: w for i, w in enumerate(word2idx)}

doc_list = Train['text'].to_list()
labels = Train['label'].astype('int').to_list()

# %%
from model import make_data
data = make_data(doc_list,word2idx,text_length)

# %%
len(data),len(labels)
# Out:
# (1353, 1353)

# %%
from model import MyDataSet

batch = Variable(torch.LongTensor(data))
labels = Variable(torch.LongTensor(labels))
loader = Data.DataLoader(MyDataSet(batch,labels), batch_size, True)

# %%
from model import SelfAttnClassifier

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

loss_function = nn.BCELoss()
model = SelfAttnClassifier(vocab_size+1, 200, 100, 1, scale=5.0, score_function='dot',activation='TanhMax')
optimizer = torch.optim.Adadelta(model.parameters(), lr=0.05)

use_gpu = torch.cuda.is_available()

if(use_gpu):
    model = model.cuda()
    loss_function = loss_function.cuda()

# %%
model.train()
for epoch in tqdm(range(100)):
    for input_ids, label in loader:
        model.zero_grad()
        preds = model(input_ids.cuda())
        loss = loss_function(preds.squeeze(), label.cuda().float()) * 100
        loss.backward(retain_graph=True)
        optimizer.step()
        input_ids.cpu()
        label.cpu()
# Out:
# 100%|██████████| 100/100 [00:14<00:00,  7.02it/s]

# %%
from model import plot_cm_matrix
plot_cm_matrix(model,batch,labels,save_url='graph/metric/TanhMaxTrainAcc.png')
# Out:
# accuracy:99.852%

# %% [markdown]
# ### test accuracy

# %%
filename = "data/Test.csv"
Test = pd.read_csv(filename)

doc_list = Test['text'].to_list()
test_labels = Test['label'].astype('int').to_list()
    
test_data = make_data(doc_list,word2idx,text_length)
len(test_data),len(test_labels)
# Out:
# (580, 580)

# %%
test_batch = Variable(torch.LongTensor(test_data))
test_labels = Variable(torch.LongTensor(test_labels))
plot_cm_matrix(model,test_batch,test_labels,save_url='graph/metric/picture6.png')
# Out:
# accuracy:85.000%

# %% [markdown]
# ### Save Model

# %%
## 保存
torch.save(model.state_dict(), 'model/TanhMaxParameter.pkl')
torch.save(model, 'model/TanhMaxModel.pkl')

## 加载
#model = SelfAttnClassifier(vocab_size+1, 30, 10, 1, scale=5.0,score_function='dot',activation='SoftMax')
#model.load_state_dict(torch.load('model/SoftmaxParameter.pkl'))

# 加载
#model = torch.load('model/SoftmaxModel.pkl')

# %% [markdown]
# ### Select Tokens

# %%
from model import SelectTokens
Pos,Neg,Neu = SelectTokens(data,labels,word2idx)

# %% [markdown]
# ### Visualization

# %%
from model import compute_coefficients
pos_index,pos_score,pos_weight,neg_index,neg_score,neg_weight,neutral_index,neutral_score,neutral_weight = compute_coefficients(model,batch,Pos,Neg,Neu,word2idx)

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_score, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_score, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_score, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Score')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture4.png')
print('Pos Mean:',np.mean(pos_score),'Pos Std:',np.std(pos_score))
print('Neg Mean:',np.mean(neg_score),'Neg Std:',np.std(neg_score))
print('Neu Mean:',np.mean(neutral_score),'Neu Std:',np.std(neutral_score))
# Out:
# Pos Mean: -0.057404579062547 Pos Std: 0.008895800727225994
# Neg Mean: -0.05138808926706439 Neg Std: 0.008057139828780601
# Neu Mean: -0.053337483382602406 Neu Std: 0.007566506931037798

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_score, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_score, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_score, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Score')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture4.png')
print('Pos Mean:',np.mean(pos_score),'Pos Std:',np.std(pos_score))
print('Neg Mean:',np.mean(neg_score),'Neg Std:',np.std(neg_score))
print('Neu Mean:',np.mean(neutral_score),'Neu Std:',np.std(neutral_score))
# Out:
# Pos Mean: 3.7379432466058504 Pos Std: 1.880104932936774
# Neg Mean: -4.286941861193026 Neg Std: 2.757765417629291
# Neu Mean: -0.10971367543496356 Neu Std: 2.12442744583558

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_weight, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_weight, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_weight, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Weight')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture5.png')
print('Pos Mean:',np.mean(pos_weight),'Pos Std:',np.std(pos_weight))
print('Neg Mean:',np.mean(neg_weight),'Neg Std:',np.std(neg_weight))
print('Neu Mean:',np.mean(neutral_weight),'Neu Std:',np.std(neutral_weight))
# Out:
# Pos Mean: -0.0019098397789913267 Pos Std: 0.000296233609553191
# Neg Mean: -0.0017092606082738967 Neg Std: 0.0002682213340101697
# Neu Mean: -0.0017742702981158244 Neu Std: 0.0002519171000978381

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_weight, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_weight, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_weight, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Weight')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture5.png')
print('Pos Mean:',np.mean(pos_weight),'Pos Std:',np.std(pos_weight))
print('Neg Mean:',np.mean(neg_weight),'Neg Std:',np.std(neg_weight))
print('Neu Mean:',np.mean(neutral_weight),'Neu Std:',np.std(neutral_weight))
# Out:
# Pos Mean: 0.16829085931550242 Pos Std: 0.14367771531989265
# Neg Mean: -0.2918269737332656 Neg Std: 0.2929152908356979
# Neu Mean: -0.007260947173343746 Neu Std: 0.06333563640622106

# %% [markdown]
# ### Exp1 -- Gradient Importance

# %%
from model import GradientImportance
GradientImportance(model,test_batch,test_labels,'TanhMax')
# Out:
# 580it [00:01, 415.37it/s]
# Both label
# 	p-value < 0.05: 496  ratio: 0.8626086956521739
# 	p-value < 0.01: 430  ratio: 0.7478260869565218
# 	Both-Mean: 0.4866419374723011 Std: 0.21561567970552956
#
# Pos
# 	p-value < 0.05: 274  ratio: 0.9383561643835616
# 	p-value < 0.01: 245  ratio: 0.839041095890411
# 	Pos-Mean: 0.5408507024988762 Std: 0.20250385869129656
#
# Neg
# 	p-value < 0.05: 222  ratio: 0.784452296819788
# 	p-value < 0.01: 185  ratio: 0.6537102473498233
# 	Neg-Mean: 0.4307092187876368 Std: 0.21444408664292328

# %% [markdown]
# ### Exp2--Feature Erasure

# %%
from model import FeatureErasure
FeatureErasure(model,test_batch,test_labels,'TanhMax')
# Out:
# 580it [00:07, 74.59it/s]
# Both label
# 	p-value < 0.05: 422  ratio: 0.7549194991055456
# 	p-value < 0.01: 396  ratio: 0.7084078711985689
# 	total num: 559  mean: 0.7630375165218719  std: 0.32131756552014107
# Pos
# 	p-value < 0.05: 172  ratio: 0.6164874551971327
# 	p-value < 0.01: 150  ratio: 0.5376344086021505
# 	total num: 279  mean: 0.6348059699822821  std: 0.3407106889698265
# Neg
# 	p-value < 0.05: 250  ratio: 0.8928571428571429
# 	p-value < 0.01: 246  ratio: 0.8785714285714286
# 	total num: 280  mean: 0.8908110932523917  std: 0.2402942879583137

# %% [markdown]
# ### Exp3--Feature Erasure ABS

# %%
from model import FeatureErasureABS
FeatureErasureABS(model,test_batch,test_labels,'TanhMax')
# Out:
# 580it [00:08, 68.59it/s]
# Both label
# 	p-value < 0.05: 422  ratio: 0.7549194991055456
# 	p-value < 0.01: 396  ratio: 0.7084078711985689
# 	total num: 559  mean: 0.7390328854105023  std: 0.3079086455794654
# Pos
# 	p-value < 0.05: 172  ratio: 0.6164874551971327
# 	p-value < 0.01: 150  ratio: 0.5376344086021505
# 	total num: 279  mean: 0.6137697581030421  std: 0.32112522316078773
# Neg
# 	p-value < 0.05: 250  ratio: 0.8928571428571429
# 	p-value < 0.01: 246  ratio: 0.8785714285714286
# 	total num: 280  mean: 0.8638486444061501  std: 0.23518070666735566

# %% [markdown]
# ### Exp4--Attention Permutation

# %%
from model import AttnPermutation
AttnPermutation(model,test_batch,test_labels,'TanhMax')
# Out:
# 580it [00:30, 19.05it/s]
# Both label
# 	total num: 580  mean: 0.013350649  std: 0.04558541
# Pos
# 	total num: 293  mean: 0.01295728  std: 0.047884583
# Neg
# 	total num: 287  mean: 0.0137522435  std: 0.043108173
#                  median                                                       \
#                   count      mean       std  min           25%           50%
# label group
# Neg   [0.,0.25)   241.0  0.012212  0.038654  0.0  1.344268e-11  1.937107e-07
#       [0.25,0.5)   36.0  0.027860  0.068691  0.0  1.534820e-06  1.330972e-04
#       [0.5,0.75)    8.0  0.000106  0.000286  0.0  2.980232e-07  5.960464e-07
#       [0.75,1.0)    2.0  0.000000  0.000000  0.0  0.000000e+00  0.000000e+00
# Pos   [0.,0.25)   145.0  0.022312  0.061655  0.0  7.152557e-07  2.148747e-04
#       [0.25,0.5)   67.0  0.008372  0.038288  0.0  0.000000e+00  3.576279e-07
#       [0.5,0.75)   24.0  0.000016  0.000054  0.0  0.000000e+00  0.000000e+00
#       [0.75,1.0)   57.0  0.000000  0.000000  0.0  0.000000e+00  0.000000e+00
#
#
#                            75%       max
# label group
# Neg   [0.,0.25)   3.199279e-04  0.253711
#       [0.25,0.5)  6.167024e-03  0.292704
#       [0.5,0.75)  1.466274e-05  0.000814
#       [0.75,1.0)  0.000000e+00  0.000000
# Pos   [0.,0.25)   7.793329e-03  0.359964
#       [0.25,0.5)  1.645088e-05  0.277947
#       [0.5,0.75)  5.215406e-07  0.000229
#       [0.75,1.0)  0.000000e+00  0.000000

# %% [markdown]
# ### Exp5--Attention Randomization

# %%
from model import AttnRandom
AttnRandom(model,test_batch,test_labels,'TanhMax')
# Out:
# 580it [00:28, 20.42it/s]
# Both label
# 	total num: 580  mean: 0.523887  std: 0.44470507
# Pos
# 	total num: 293  mean: 0.53693426  std: 0.4515394
# Neg
# 	total num: 287  mean: 0.51056695  std: 0.4372163
#                  median                                                        \
#                   count      mean       std           min       25%       50%
# label group
# Neg   [0.,0.25)    33.0  0.418686  0.377085  0.000000e+00  0.010515  0.335374
#       [0.25,0.5)  122.0  0.550516  0.439378  0.000000e+00  0.014309  0.661137
#       [0.5,0.75)   57.0  0.484063  0.457115  0.000000e+00  0.000114  0.465931
#       [0.75,1.0)   75.0  0.506154  0.446255  1.414901e-15  0.001534  0.469985
# Pos   [0.,0.25)    33.0  0.539825  0.431886  2.192168e-07  0.080845  0.644040
#       [0.25,0.5)  105.0  0.629445  0.430478  1.394447e-09  0.101711  0.939528
#       [0.5,0.75)   58.0  0.380221  0.453045  0.000000e+00  0.000452  0.077306
#       [0.75,1.0)   97.0  0.529515  0.461768  0.000000e+00  0.000212  0.791838
#
#
#                        75%  max
# label group
# Neg   [0.,0.25)   0.761786  1.0
#       [0.25,0.5)  0.999597  1.0
#       [0.5,0.75)  0.999608  1.0
#       [0.75,1.0)  0.999132  1.0
# Pos   [0.,0.25)   0.991994  1.0
#       [0.25,0.5)  0.999824  1.0
#       [0.5,0.75)  0.993002  1.0
#       [0.75,1.0)  0.999744  1.0

# %% [markdown]
# ### check selected tokens

# %%
pos_df = pd.DataFrame(zip(pos_index,pos_score),columns=['index','value'])
pos_top_index = pos_df.sort_values(by='value',ascending=False)['index'].values[:50]
pos_top_words = []
for item in pos_top_index:
    pos_top_words.append(idx2word[item])
print(pos_top_words)
print(len(pos_df))
# Out:
# ['broadcast', 'news', 'tv', 'final', 'period', 'stars', 'pit', 'area', 'points', 'washington', 'deal', 'group', 'canadian', 'hard', 'canada', 'local', 'pick', 'b', 'l', 'roger', 'p', 'show', 'shots', 'stupid', 'beat', 'move', 'north', 'exactly', 'during', 'w', 'german', 'vs', 'put', 'taken', 'speaking', 'station', 'results', 'own', 'played', 'next', 'check', 'late']
# 42

# %%
neg_df = pd.DataFrame(zip(neg_index,neg_score),columns=['index','value'])
neg_top_index = neg_df.sort_values(by='value',ascending=True)['index'].values[:50]
neg_top_words = []
for item in neg_top_index:
    neg_top_words.append(idx2word[item])
print(neg_top_words)
print(len(neg_df))
# Out:
# ['devils', 'gift', 'perhaps', 'quiet', 'push', 'trash', 'japan', 'rare', 'experience', 'run', 'sharp', 'pitched', 'store', 'wise', 'pot', 'box', 'idea', 'complaint', 'stadium', 'either', 'average', 'boredom', 'passion', 'letter', 'improbable', 'intelligence', 'every', 'plays', 'wide', 'keeps', 'road', 'ron', 'nelson', 'christian', 'hip', 'mundane', 'meaning', 'kill', 'minor', 'mouth', 'joseph', 'wears', 'missing', 'barry', 'day', 'runs', 'films', 'ultimately', 'talking', 'hit']
# 134

# %%
neu_df = pd.DataFrame(zip(neutral_index,neutral_score),columns=['index','value'])
neu_top_index1 = neu_df.sort_values(by='value',ascending=True)['index'].values[:50]
neu_top_index2 = neu_df.sort_values(by='value',ascending=False)['index'].values[:50]
neu_top_words = []
for item in neu_top_index1:
    neu_top_words.append(idx2word[item])
for item in neu_top_index2:
    neu_top_words.append(idx2word[item])
print(neu_top_words)
print(len(neu_df))
# Out:
# ['despite', 'this', 'should', 'shut', 'violence', 'half', 'still', 'loss', 'hour', 'special', 'george', 'saw', 'point', 'opportunity', 'unlike', 'answers', 'left', 'set', 'room', 've', 'safe', 'probably', 'while', 'people', 'ed', 'entertaining', 'paid', 'were', 'though', 'birthday', 'shame', 'last', 'reached', 'white', 'memorial', 'row', 'slow', 'means', 'enjoy', 'pa', 'among', 'open', 'dream', 'trend', 'boring', 'being', 'excellent', 'standard', 'year', 'justice', 'exist', 'imagine', 'board', 'fall', 'closely', 'small', 'learning', 'catch', 'win', 'chicago', 'direction', 'suggests', 'please', 'neat', 'sucked', 'evidence', 'have', 'boys', 'study', 'credit', 'sitting', 'really', 'better', 'blood', 'expect', 'mainly', 'wondered', 'outcome', 'card', 'someone', 'behind', 'choices', 'save', 'faces', 'trouble', 'individual', 'york', 'kind', 'worth', 'winners', 'reading', 'get', 'america', 'john', 'began', 'married', 'think', 'aim', 'directly', 'whenever']
# 308
