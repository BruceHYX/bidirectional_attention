# %% [markdown]
# ### Attention of Softmax(SST)

# %%
import pandas as pd
import torch.utils.data as Data
import torch.optim as optim
from torch.autograd import Variable
import torch
import pickle
from torch import optim
import torch.nn as nn
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
filename = 'data/local_dict.pkl'
path = filename
dict_file = open(path, 'rb')

vocab  = pickle.load(dict_file)[0]
print('length of vocabulary: ',len(vocab))
dict_file.close()

filename = "data/train_seq.pkl"
path = filename
train_file = open(path, 'rb')

Train  = pickle.load(train_file)
dict_file.close()
# Out:
# length of vocabulary:  16174

# %%
labels = list()
doc_idx = list()
for item in Train:
    doc_idx.append(item[0])
    if item[1] == 1:
        labels.append(1.)
    else:
        labels.append(0.)
        
vocab_size = 8000
text_length = 30
batch_size = 100
epoch_num = 100

word2idx = {'[PAD]':0}
for i, w in enumerate(vocab[:vocab_size]):
    word2idx[w] = i + 1
idx2word = {i: w for i, w in enumerate(word2idx)}

doc_list = list()
for i in range(len(doc_idx)):
    temp = list()
    for idx in doc_idx[i]:
        if idx in idx2word.keys():
            temp.append(idx2word[idx])
    doc_list.append(' '.join(temp))

# %%
from model import make_data
data = make_data(doc_list,word2idx,text_length)

# %%
from model import MyDataSet

batch = Variable(torch.LongTensor(data))
labels = Variable(torch.LongTensor(labels))
loader = Data.DataLoader(MyDataSet(batch,labels), batch_size, True)

# %%
from model import SelfAttnClassifier

loss_function = nn.BCELoss()
model = SelfAttnClassifier(vocab_size+1, 200, 100, 1, scale=5.0,score_function='dot',activation='SoftMax')
optimizer = torch.optim.Adadelta(model.parameters(), lr=0.5)

use_gpu = torch.cuda.is_available()

if(use_gpu):
    model = model.cuda()
    loss_function = loss_function.cuda()

# %%
model.train()
for epoch in tqdm(range(100)):
    for input_ids, label in loader:
        model.zero_grad()
        preds = model(input_ids.cuda())
        loss = loss_function(preds.squeeze(), label.cuda().float()) * 100
        loss.backward(retain_graph=True)
        optimizer.step()
        input_ids.cpu()
        label.cpu()
# Out:
# 100%|██████████| 100/100 [00:52<00:00,  1.90it/s]

# %%
from model import plot_cm_matrix
plot_cm_matrix(model,batch,labels,save_url='graph/metric/SoftmaxTrainAcc.png')
# Out:
# accuracy:84.046%

# %% [markdown]
# ### test accuracy

# %%
filename = "data/test_seq.pkl"
test_file = open(filename, 'rb')

Test  = pickle.load(test_file)
dict_file.close()

test_labels = list()
doc_idx = list()
for item in Test:
    doc_idx.append(item[0])
    if item[1] == 1:
        test_labels.append(1)
    else:
        test_labels.append(0)
    
doc_list = list()
for i in range(len(doc_idx)):
    temp = list()
    for idx in doc_idx[i]:
        if idx in idx2word.keys():
            temp.append(idx2word[idx])
    doc_list.append(' '.join(temp))
    
test_data = make_data(doc_list,word2idx,text_length)
len(test_data),len(test_labels)
# Out:
# (1821, 1821)

# %%
test_batch = Variable(torch.LongTensor(test_data))
test_labels = Variable(torch.LongTensor(test_labels))
plot_cm_matrix(model,test_batch,test_labels,save_url='graph/metric/picture3.png')
# Out:
# accuracy:78.748%

# %% [markdown]
# ### Save Model

# %%
## 保存
torch.save(model.state_dict(), 'model/SoftmaxParameter.pkl')
torch.save(model, 'model/SoftmaxModel.pkl')

## 加载
#model = SelfAttnClassifier(vocab_size+1, 30, 10, 1, scale=5.0,score_function='dot',activation='SoftMax')
#model.load_state_dict(torch.load('model/SoftmaxParameter.pkl'))

# 加载
#model = torch.load('model/SoftmaxModel.pkl')

# %% [markdown]
# ### Select Tokens

# %%
from model import SelectTokens
Pos,Neg,Neu = SelectTokens(data,labels,word2idx)

# %% [markdown]
# ### Visualization

# %%
from model import compute_coefficients
pos_index,pos_score,pos_weight,neg_index,neg_score,neg_weight,neutral_index,neutral_score,neutral_weight = compute_coefficients(model,batch,Pos,Neg,Neu,word2idx)

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_score, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_score, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_score, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Score')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture1.png')
print('Pos Mean:',np.mean(pos_score),'Pos Std:',np.std(pos_score))
print('Neg Mean:',np.mean(neg_score),'Neg Std:',np.std(neg_score))
print('Neu Mean:',np.mean(neutral_score),'Neu Std:',np.std(neutral_score))
# Out:
# Pos Mean: -1.596461490562675 Pos Std: 1.3193128732992494
# Neg Mean: -0.8144989245443434 Neg Std: 1.132774686261296
# Neu Mean: -1.2484583172396304 Neu Std: 1.1666308430494634

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_weight, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_weight, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_weight, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Weight')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture2.png')
print('Pos Mean:',np.mean(pos_weight),'Pos Std:',np.std(pos_weight))
print('Neg Mean:',np.mean(neg_weight),'Neg Std:',np.std(neg_weight))
print('Neu Mean:',np.mean(neutral_weight),'Neu Std:',np.std(neutral_weight))
# Out:
# Pos Mean: 0.1429345321651473 Pos Std: 0.099232778557257
# Neg Mean: 0.22956341100649785 Neg Std: 0.12462105496957213
# Neu Mean: 0.14312617935863603 Neu Std: 0.09242039680438269

# %% [markdown]
# ### Exp1--Feature Importance

# %%
from model import GradientImportance
GradientImportance(model,test_batch,test_labels,'Softmax')
# Out:
# 1821it [00:04, 450.96it/s]
# Both label
# 	p-value < 0.05: 343  ratio: 0.18835804503020318
# 	p-value < 0.01: 163  ratio: 0.08951125755079627
# 	Both-Mean: -0.029137963714271933 Std: 0.25493444397181103
#
# Pos
# 	p-value < 0.05: 177  ratio: 0.19471947194719472
# 	p-value < 0.01: 74  ratio: 0.0814081408140814
# 	Pos-Mean: -0.021117461121571746 Std: 0.2529352366661917
#
# Neg
# 	p-value < 0.05: 166  ratio: 0.18201754385964913
# 	p-value < 0.01: 89  ratio: 0.09758771929824561
# 	Neg-Mean: -0.037132083074759285 Std: 0.2566623166264166

# %% [markdown]
# ### Exp2--Feature Erasure

# %%
from model import FeatureErasure
FeatureErasure(model,test_batch,test_labels,'Softmax')
# Out:
# 1821it [00:25, 71.16it/s]
# Both label
# 	p-value < 0.05: 704  ratio: 0.38660076880834704
# 	p-value < 0.01: 456  ratio: 0.2504118616144975
# 	total num: 1821  mean: 0.06644027092394492  std: 0.34899417492458124
# Pos
# 	p-value < 0.05: 416  ratio: 0.45764576457645767
# 	p-value < 0.01: 286  ratio: 0.3146314631463146
# 	total num: 909  mean: 0.2563299747394969  std: 0.30776986569750275
# Neg
# 	p-value < 0.05: 288  ratio: 0.3157894736842105
# 	p-value < 0.01: 170  ratio: 0.18640350877192982
# 	total num: 912  mean: -0.12282479570800332  std: 0.2775279514029795

# %% [markdown]
# ### Exp3--Feature Erasure ABS

# %%
from model import FeatureErasureABS
FeatureErasureABS(model,test_batch,test_labels,'Softmax')
# Out:
# 1821it [00:26, 67.98it/s]
# Both label
# 	p-value < 0.05: 1819  ratio: 0.9989017023613399
# 	p-value < 0.01: 1812  ratio: 0.9950576606260296
# 	total num: 1821  mean: 0.7593889821499303  std: 0.15152268802781646
# Pos
# 	p-value < 0.05: 907  ratio: 0.9977997799779978
# 	p-value < 0.01: 900  ratio: 0.9900990099009901
# 	total num: 909  mean: 0.7398804733406341  std: 0.1568014859441123
# Neg
# 	p-value < 0.05: 912  ratio: 1.0
# 	p-value < 0.01: 912  ratio: 1.0
# 	total num: 912  mean: 0.77883331823288  std: 0.1434555180447524

# %% [markdown]
# ### Exp4--Attention Permutation

# %%
from model import AttnPermutation
AttnPermutation(model,test_batch,test_labels,'Softmax')
# Out:
# 1821it [01:27, 20.88it/s]
# Both label
# 	total num: 1821  mean: 0.31283298  std: 0.2692188
# Pos
# 	total num: 909  mean: 0.38114887  std: 0.29983637
# Neg
# 	total num: 912  mean: 0.24474181  std: 0.21406749
#                  median                                                    \
#                   count      mean       std       min       25%       50%
# label group
# Neg   [0.,0.25)   807.0  0.250306  0.204173  0.002061  0.077020  0.211326
#       [0.25,0.5)   89.0  0.204006  0.267995  0.001099  0.009001  0.084667
#       [0.5,0.75)   13.0  0.233182  0.356807  0.002874  0.008168  0.010418
#       [0.75,1.0)    3.0  0.006465  0.001859  0.004747  0.005479  0.006211
# Pos   [0.,0.25)   793.0  0.321558  0.252763  0.000354  0.113906  0.266647
#       [0.25,0.5)  111.0  0.791397  0.276617  0.000160  0.778904  0.902693
#       [0.5,0.75)    5.0  0.724755  0.392277  0.101409  0.568636  0.977891
#
#
#                        75%       max
# label group
# Neg   [0.,0.25)   0.366284  0.951932
#       [0.25,0.5)  0.298566  0.969714
#       [0.5,0.75)  0.372642  0.987044
#       [0.75,1.0)  0.007324  0.008438
# Pos   [0.,0.25)   0.480485  0.959500
#       [0.25,0.5)  0.971753  0.988933
#       [0.5,0.75)  0.986522  0.989314

# %% [markdown]
# ### Exp5--Attention Randomization

# %%
from model import AttnRandom
AttnRandom(model,test_batch,test_labels,'Softmax')
# Out:
# 1821it [01:19, 23.03it/s]
# Both label
# 	total num: 1821  mean: 0.35421023  std: 0.34734145
# Pos
# 	total num: 909  mean: 0.40764508  std: 0.37574136
# Neg
# 	total num: 912  mean: 0.3009511  std: 0.3074016
#                  median                                                        \
#                   count      mean       std           min       25%       50%
# label group
# Neg   [0.,0.25)   807.0  0.312885  0.308558  7.456596e-06  0.036035  0.200914
#       [0.25,0.5)   89.0  0.212207  0.276562  1.127557e-07  0.006523  0.094681
#       [0.5,0.75)   13.0  0.236579  0.362206  7.037409e-06  0.001215  0.012604
#       [0.75,1.0)    3.0  0.002299  0.002068  7.596232e-05  0.001366  0.002655
# Pos   [0.,0.25)   793.0  0.345735  0.345502  2.753735e-05  0.027936  0.211493
#       [0.25,0.5)  111.0  0.835167  0.290909  5.364418e-05  0.844318  0.975882
#       [0.5,0.75)    5.0  0.735561  0.392872  1.116831e-01  0.578326  0.989278
#
#
#                        75%       max
# label group
# Neg   [0.,0.25)   0.550015  0.989952
#       [0.25,0.5)  0.309485  0.995254
#       [0.5,0.75)  0.383002  0.999497
#       [0.75,1.0)  0.003410  0.004165
# Pos   [0.,0.25)   0.622762  0.999998
#       [0.25,0.5)  0.998754  1.000000
#       [0.5,0.75)  0.998563  0.999955

# %% [markdown]
# ### check selected tokens

# %%
pos_df = pd.DataFrame(zip(pos_index,pos_score),columns=['index','value'])
pos_top_index = pos_df.sort_values(by='value',ascending=False)['index'].values[:50]
pos_top_words = []
for item in pos_top_index:
    pos_top_words.append(idx2word[item])
print(pos_top_words)
print(len(pos_df))
# Out:
# ['teen', 'dong', 'cute', 'view', 'mixed', 'mention', 'required', 'nice', 'male', 'middle', 'money', 'cult', 'detail', 'tension', 'living', 'creativity', 'insightful', 'minded', 'murder', 'creepy', 'conviction', 'post', 'huge', 'martha', 'wish', 'unexpected', 'spent', 'miss', 'edge', 'viewer', 'sentimentality', 'line', 'guys', 'oscar', 'slight', 'grief', 'gay', 'mark', 'slapstick', 'late', 'dignity', 'thrills', 'credit', 'fanciful', 'boy', 'meets', 'painful', 'roots', 'challenging', 'exercise']
# 293

# %%
neg_df = pd.DataFrame(zip(neg_index,neg_score),columns=['index','value'])
neg_top_index = neg_df.sort_values(by='value',ascending=True)['index'].values[:50]
neg_top_words = []
for item in neg_top_index:
    neg_top_words.append(idx2word[item])
print(neg_top_words)
print(len(neg_df))
# Out:
# ['man', 'do', 'beautifully', 'leads', 'treasure', 'emotionally', 'style', 'weight', 'depressing', 'watchable', 'greek', 'hip', 'mediocre', 'none', 'ugly', 'saccharine', 'story', 'engaging', 'intriguing', 'bullock', 'frustrating', 'unpleasant', 'mad', 'excitement', 'queen', 'aside', 'leave', 'sound', 'cinematic', 'subtle', 'curiously', 'ways', 'god', 'repetitive', 'served', 'nature', 'mostly', 'moves', 'eye', 'pity', 'remain', 'offer', 'question', 'attempt', 'hearted', 'must', 'form', 'hide', 'lacking', 'levels']
# 277

# %%
neu_df = pd.DataFrame(zip(neutral_index,neutral_score),columns=['index','value'])
neu_top_index1 = neu_df.sort_values(by='value',ascending=True)['index'].values[:50]
neu_top_index2 = neu_df.sort_values(by='value',ascending=False)['index'].values[:50]
neu_top_words = []
for item in neu_top_index1:
    neu_top_words.append(idx2word[item])
for item in neu_top_index2:
    neu_top_words.append(idx2word[item])
print(neu_top_words)
print(len(neu_df))
# Out:
# ['before', 'avoid', 'way', 'something', 'one', 'looking', 'light', 'never', 'performance', 'interesting', 'give', 'self', 'moving', 'actors', 'know', 'french', 'beautiful', 'american', 'effort', 'certain', 'whole', 'winning', 'script', 'three', 'this', 'above', 'sweet', 'series', 'dark', 'brilliant', 'country', 'bit', 'lot', 'allen', 'jagger', 'imax', 'predictable', 'manner', 'john', 'actually', 'years', 'master', 'right', 'slow', 'fast', 'however', 'acting', 'wit', 'sexy', 'crush', 'adorably', 'bowl', 'tooth', 'rigid', 'scored', 'growth', 'sublimely', 'polson', 'creatures', 'bled', 'coincidence', 'bombastic', 'neat', 'implies', 'popping', 'insistently', 'shakes', 'technological', 'via', 'intent', 'ingenuity', 'legend', 'larson', 'chateau', 'journalist', 'fascination', 'swiftly', 'benefits', 'negotiate', 'illness', 'democratic', 'transcendent', 'william', 'relying', 'payami', 'variation', 'pleased', 'strict', 'broke', 'tupac', 'bikes', 'pill', 'outlandish', 'saga', 'twinkle', 'bodice', 'rocky', 'obstacles', 'sparse', 'presentation']
# 1339
