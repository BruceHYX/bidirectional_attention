# %% [markdown]
# ### Attention of TanhMax(SST)

# %%
import pandas as pd
import torch.utils.data as Data
import torch.optim as optim
from torch.autograd import Variable
import torch
import pickle
from torch import optim
import torch.nn as nn
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
filename = 'data/local_dict.pkl'
path = filename
dict_file = open(path, 'rb')

vocab  = pickle.load(dict_file)[0]
print('length of vocabulary: ',len(vocab))
dict_file.close()

filename = "data/train_seq.pkl"
path = filename
train_file = open(path, 'rb')

Train  = pickle.load(train_file)
dict_file.close()
# Out:
# length of vocabulary:  16174

# %%
labels = list()
doc_idx = list()
for item in Train:
    doc_idx.append(item[0])
    if item[1] == 1:
        labels.append(1.)
    else:
        labels.append(0.)
        
vocab_size = 8000
text_length = 30
batch_size = 100
epoch_num = 100

word2idx = {'[PAD]':0}
for i, w in enumerate(vocab[:vocab_size]):
    word2idx[w] = i + 1
idx2word = {i: w for i, w in enumerate(word2idx)}

doc_list = list()
for i in range(len(doc_idx)):
    temp = list()
    for idx in doc_idx[i]:
        if idx in idx2word.keys():
            temp.append(idx2word[idx])
    doc_list.append(' '.join(temp))

# %%
from model import make_data
data = make_data(doc_list,word2idx,text_length)

# %%
from model import MyDataSet

batch = Variable(torch.LongTensor(data))
labels = Variable(torch.LongTensor(labels))
loader = Data.DataLoader(MyDataSet(batch,labels), batch_size, True)

# %%
def TanhMax(a):
    return (torch.exp(a) - torch.exp(-a)) / (torch.exp(a) + torch.exp(-a)).sum(dim=-1).unsqueeze(dim=-1)
    
class SelfAttnClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim=1, scale=1,score_function='dot', activation='TanhMax'):
        super(SelfAttnClassifier, self).__init__()
        
        self.embeddings = nn.Embedding(vocab_size, embed_dim)
        self.embeddings.weight.data.uniform_(-0.1, 0.1)
        self.scale = scale
        self.Wk = nn.Linear(embed_dim,hidden_dim)
        self.Wv = nn.Linear(embed_dim,hidden_dim)
        self.Wq = nn.Linear(embed_dim,hidden_dim)
        self.score_function = score_function
        if self.score_function == 'additive':
            self.v = nn.Parameter(torch.randn(hidden_dim, 1))
        
        if activation.lower() == 'softmax':
            self.activate = nn.Softmax(dim=-1)
        elif activation.lower() == 'tanhmax':
            self.activate = TanhMax
        elif activation.lower() == 'tanh':
            self.activate = nn.Tanh()
        
        self.dropout = nn.Dropout(0.5)
        self.dense = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()
        

    # batch_size * sent_l * dim
    def forward(self, seq_ids, labels=None):
        seq_embs = self.embeddings(seq_ids)
        
        Q = self.Wq(seq_embs)
        K = self.Wk(seq_embs)
        V = self.Wv(seq_embs)
        
        if self.score_function == 'dot':
            scores = (Q*K).sum(dim=-1) / self.scale
        elif self.score_function == 'additive':
            scores = torch.matmul(nn.Tanh()(K+Q),self.v).squeeze(-1)
            
        if labels is None:
            scores = scores 
        else:
            scores = scores * labels.unsqueeze(dim=-1)
            
        attn = self.activate(scores)
        final_vec = torch.bmm(attn.unsqueeze(1), V).squeeze(1)
        senti_scores = self.dense(self.dropout(final_vec))
        probs = self.sigmoid(senti_scores)
        return probs

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

loss_function = nn.BCELoss()
model = SelfAttnClassifier(vocab_size+1, 200, 100, 1, scale=5.0, score_function='dot',activation='TanhMax')
optimizer = torch.optim.Adadelta(model.parameters(), lr=0.5)

use_gpu = torch.cuda.is_available()

if(use_gpu):
    model = model.cuda()
    loss_function = loss_function.cuda()

# %%
model.train()
for epoch in tqdm(range(100)):
    for input_ids, label in loader:
        model.zero_grad()
        preds = model(input_ids.cuda())
        loss = loss_function(preds.squeeze(), label.cuda().float()) * 100
        loss.backward(retain_graph=True)
        optimizer.step()
        input_ids.cpu()
        label.cpu()
# Out:
# 100%|██████████| 100/100 [00:57<00:00,  1.73it/s]

# %%
from model import plot_cm_matrix
plot_cm_matrix(model,batch,labels,save_url='graph/metric/TanhMaxTrainAcc.png')
# Out:
# accuracy:99.986%

# %% [markdown]
# ### test accuracy

# %%
filename = "data/test_seq.pkl"
test_file = open(filename, 'rb')

Test  = pickle.load(test_file)
dict_file.close()

test_labels = list()
doc_idx = list()
for item in Test:
    doc_idx.append(item[0])
    if item[1] == 1:
        test_labels.append(1)
    else:
        test_labels.append(0)
    
doc_list = list()
for i in range(len(doc_idx)):
    temp = list()
    for idx in doc_idx[i]:
        if idx in idx2word.keys():
            temp.append(idx2word[idx])
    doc_list.append(' '.join(temp))
    
test_data = make_data(doc_list,word2idx,text_length)
len(test_data),len(test_labels)
# Out:
# (1821, 1821)

# %%
test_batch = Variable(torch.LongTensor(test_data))
test_labels = Variable(torch.LongTensor(test_labels))
plot_cm_matrix(model,test_batch,test_labels,save_url='graph/metric/picture6.png')
# Out:
# accuracy:87.864%

# %% [markdown]
# ### Save Model

# %%
## 保存
torch.save(model.state_dict(), 'model/TanhMaxParameter.pkl')
torch.save(model, 'model/TanhMaxModel.pkl')

## 加载
#model = SelfAttnClassifier(vocab_size+1, 30, 10, 1, scale=5.0,score_function='dot',activation='SoftMax')
#model.load_state_dict(torch.load('model/SoftmaxParameter.pkl'))

# 加载
#model = torch.load('model/TanhMaxModel.pkl')

# %% [markdown]
# ### Select Tokens

# %%
from model import SelectTokens
Pos,Neg,Neu = SelectTokens(data,labels,word2idx)

# %% [markdown]
# ### Visualization

# %%
from model import compute_coefficients
pos_index,pos_score,pos_weight,neg_index,neg_score,neg_weight,neutral_index,neutral_score,neutral_weight = compute_coefficients(model,batch,Pos,Neg,Neu,word2idx)

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_score, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_score, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_score, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Score')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture4.png')
print('Pos Mean:',np.mean(pos_score),'Pos Std:',np.std(pos_score))
print('Neg Mean:',np.mean(neg_score),'Neg Std:',np.std(neg_score))
print('Neu Mean:',np.mean(neutral_score),'Neu Std:',np.std(neutral_score))
# Out:
# Pos Mean: 3.1862684565281603 Pos Std: 1.633938016536714
# Neg Mean: -4.585568625641906 Neg Std: 1.627743034663107
# Neu Mean: -0.15408284209363993 Neu Std: 1.9074000907706774

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(neutral_index, neutral_weight, 'x', label='Neutral',color='green')
plt.plot(pos_index, pos_weight, '+',label='Pos',color='orange')
plt.plot(neg_index, neg_weight, '.', label='Neg',color='blue')
plt.xlabel('Token Index')
plt.ylabel('Attention Weight')
plt.grid(linestyle='--')
plt.legend()
plt.savefig('graph/metric/picture5.png')
print('Pos Mean:',np.mean(pos_weight),'Pos Std:',np.std(pos_weight))
print('Neg Mean:',np.mean(neg_weight),'Neg Std:',np.std(neg_weight))
print('Neu Mean:',np.mean(neutral_weight),'Neu Std:',np.std(neutral_weight))
# Out:
# Pos Mean: 0.1303855181406704 Pos Std: 0.12856354012501062
# Neg Mean: -0.28429990934601385 Neg Std: 0.20931589766978587
# Neu Mean: -0.006536530719988796 Neu Std: 0.06123159174421148

# %% [markdown]
# ### Exp1 -- Gradient Importance

# %%
from model import GradientImportance
GradientImportance(model,test_batch,test_labels,'TanhMax')
# Out:
# 1821it [00:04, 405.59it/s]
# Both label
# 	p-value < 0.05: 1812  ratio: 0.9950576606260296
# 	p-value < 0.01: 1802  ratio: 0.9895661724327293
# 	Both-Mean: 0.8805194533070584 Std: 0.13779459285705473
#
# Pos
# 	p-value < 0.05: 906  ratio: 0.9966996699669967
# 	p-value < 0.01: 901  ratio: 0.9911991199119912
# 	Pos-Mean: 0.905523069066018 Std: 0.10575000919681125
#
# Neg
# 	p-value < 0.05: 906  ratio: 0.993421052631579
# 	p-value < 0.01: 901  ratio: 0.9879385964912281
# 	Neg-Mean: 0.8555980862841479 Std: 0.15975532662565897

# %% [markdown]
# ### Exp2--Feature Erasure

# %%
from model import FeatureErasure
FeatureErasure(model,test_batch,test_labels,'TanhMax')
# Out:
# 1821it [00:23, 78.03it/s]
# Both label
# 	p-value < 0.05: 1820  ratio: 0.99945085118067
# 	p-value < 0.01: 1820  ratio: 0.99945085118067
# 	total num: 1821  mean: 0.9789907670265916  std: 0.06543017410423911
# Pos
# 	p-value < 0.05: 909  ratio: 1.0
# 	p-value < 0.01: 909  ratio: 1.0
# 	total num: 909  mean: 0.9860966614420448  std: 0.02611467804531358
# Neg
# 	p-value < 0.05: 911  ratio: 0.9989035087719298
# 	p-value < 0.01: 911  ratio: 0.9989035087719298
# 	total num: 912  mean: 0.9719082472638205  std: 0.08813574749090482

# %% [markdown]
# ### Exp3--Feature Erasure ABS

# %%
from model import FeatureErasureABS
FeatureErasureABS(model,test_batch,test_labels,'TanhMax')
# Out:
# 1821it [00:27, 65.90it/s]
# Both label
# 	p-value < 0.05: 1819  ratio: 0.9989017023613399
# 	p-value < 0.01: 1816  ratio: 0.9972542559033498
# 	total num: 1821  mean: 0.962380394712079  std: 0.07118120273782046
# Pos
# 	p-value < 0.05: 909  ratio: 1.0
# 	p-value < 0.01: 909  ratio: 1.0
# 	total num: 909  mean: 0.9722868145389493  std: 0.05040031531684667
# Neg
# 	p-value < 0.05: 910  ratio: 0.9978070175438597
# 	p-value < 0.01: 907  ratio: 0.9945175438596491
# 	total num: 912  mean: 0.9525065617925339  std: 0.08596346584489918

# %% [markdown]
# ### Exp4--Attention Permutation

# %%
from model import AttnPermutation
AttnPermutation(model,test_batch,test_labels,'TanhMax')
# Out:
# 1821it [01:31, 19.95it/s]
# Both label
# 	total num: 1821  mean: 0.30045798  std: 0.36231637
# Pos
# 	total num: 909  mean: 0.31958243  std: 0.36960322
# Neg
# 	total num: 912  mean: 0.28139642  std: 0.35387766
#                  median                                                        \
#                   count      mean       std           min       25%       50%
# label group
# Neg   [0.,0.25)   290.0  0.270850  0.367347  0.000000e+00  0.000035  0.025318
#       [0.25,0.5)  500.0  0.266878  0.351348  0.000000e+00  0.000176  0.028765
#       [0.5,0.75)  111.0  0.362588  0.332350  9.656874e-09  0.069291  0.280874
#       [0.75,1.0)   11.0  0.400077  0.209015  5.665541e-02  0.320321  0.332919
# Pos   [0.,0.25)   274.0  0.272713  0.377776  0.000000e+00  0.000170  0.018859
#       [0.25,0.5)  518.0  0.312408  0.370303  0.000000e+00  0.000479  0.064063
#       [0.5,0.75)  106.0  0.446047  0.318789  4.942290e-11  0.121951  0.530623
#       [0.75,1.0)   11.0  0.606273  0.205488  3.235089e-01  0.393961  0.674937
#
#
#                        75%       max
# label group
# Neg   [0.,0.25)   0.479948  0.999997
#       [0.25,0.5)  0.487103  1.000000
#       [0.5,0.75)  0.650821  1.000000
#       [0.75,1.0)  0.591503  0.685136
# Pos   [0.,0.25)   0.551066  1.000000
#       [0.25,0.5)  0.653424  0.999999
#       [0.5,0.75)  0.677198  1.000000
#       [0.75,1.0)  0.682339  0.915117

# %% [markdown]
# ### Exp5--Attention Randomization

# %%
from model import AttnRandom
AttnRandom(model,test_batch,test_labels,'TanhMax')
# Out:
# 1821it [01:16, 23.68it/s]
# Both label
# 	total num: 1821  mean: 0.5153569  std: 0.45438328
# Pos
# 	total num: 909  mean: 0.494941  std: 0.45615077
# Neg
# 	total num: 912  mean: 0.53570575  std: 0.45169744
#                  median                                                        \
#                   count      mean       std           min       25%       50%
# label group
# Neg   [0.,0.25)   290.0  0.534869  0.453476  0.000000e+00  0.000399  0.642137
#       [0.25,0.5)  500.0  0.528855  0.450709  0.000000e+00  0.000328  0.674841
#       [0.5,0.75)  111.0  0.560728  0.458481  0.000000e+00  0.002670  0.775329
#       [0.75,1.0)   11.0  0.616645  0.446283  1.879534e-11  0.211621  0.901057
# Pos   [0.,0.25)   274.0  0.477717  0.452968  0.000000e+00  0.000559  0.433515
#       [0.25,0.5)  518.0  0.498003  0.458459  0.000000e+00  0.000369  0.498347
#       [0.5,0.75)  106.0  0.535118  0.454864  0.000000e+00  0.001081  0.632273
#       [0.75,1.0)   11.0  0.392627  0.485986  5.364418e-07  0.005311  0.062494
#
#
#                        75%  max
# label group
# Neg   [0.,0.25)   0.999680  1.0
#       [0.25,0.5)  0.999587  1.0
#       [0.5,0.75)  0.999998  1.0
#       [0.75,1.0)  0.999724  1.0
# Pos   [0.,0.25)   0.998878  1.0
#       [0.25,0.5)  0.999906  1.0
#       [0.5,0.75)  0.999086  1.0
#       [0.75,1.0)  0.999994  1.0

# %% [markdown]
# ### check selected tokens

# %%
pos_df = pd.DataFrame(zip(pos_index,pos_score),columns=['index','value'])
pos_top_index = pos_df.sort_values(by='value',ascending=False)['index'].values[:50]
pos_top_words = []
for item in pos_top_index:
    pos_top_words.append(idx2word[item])
print(pos_top_words)
print(len(pos_df))
# Out:
# ['teen', 'dong', 'nice', 'unexpected', 'stirring', 'money', 'view', 'murder', 'required', 'son', 'insightful', 'detail', 'tension', 'martha', 'thrills', 'slapstick', 'bland', 'cute', 'post', 'late', 'creativity', 'painful', 'reading', 'creepy', 'minded', 'edge', 'living', 'middle', 'damned', 'said', 'gay', 'male', 'slight', 'pretension', 'provocative', 'though', 'single', 'powerful', 'wish', 'intelligent', 'exercise', 'characterizations', 'cult', 'boy', 'mention', 'waste', 'viewer', 'brings', 'worst', 'miss']
# 293

# %%
neg_df = pd.DataFrame(zip(neg_index,neg_score),columns=['index','value'])
neg_top_index = neg_df.sort_values(by='value',ascending=True)['index'].values[:50]
neg_top_words = []
for item in neg_top_index:
    neg_top_words.append(idx2word[item])
print(neg_top_words)
print(len(neg_df))
# Out:
# ['pointless', 'sleep', 'shoot', 'wannabe', 'produce', 'happening', 'plain', 'leaving', 'gags', 'failure', 'loose', 'afraid', 'glass', 'depth', 'madonna', 'buffs', 'leaden', 'tiresome', 'suffers', 'product', 'ghost', 'gripping', 'indeed', 'offensive', 'formulaic', 'soggy', 'longer', 'identity', 'sadly', 'endless', 'stealing', 'considering', 'aged', 'guilty', 'pile', 'irritating', 'generic', 'fatal', 'esther', 'clumsily', 'unless', 'except', 'lifeless', 'trifle', 'visceral', 'intentioned', 'relentless', 'paper', 'britney', 'green']
# 253

# %%
neu_df = pd.DataFrame(zip(neutral_index,neutral_score),columns=['index','value'])
neu_top_index1 = neu_df.sort_values(by='value',ascending=True)['index'].values[:50]
neu_top_index2 = neu_df.sort_values(by='value',ascending=False)['index'].values[:50]
neu_top_words = []
for item in neu_top_index1:
    neu_top_words.append(idx2word[item])
for item in neu_top_index2:
    neu_top_words.append(idx2word[item])
print(neu_top_words)
print(len(neu_df))
# Out:
# ['adorably', 'victims', 'alternating', 'arrived', 'effectively', 'unlike', 'harris', 'positive', 'respect', 'chilly', 'porn', 'north', 'despair', 'verve', 'sillier', 'engages', 'moonlight', 'negotiate', 'tears', 'transcendent', 'teasing', 'faith', 'delivers', 'sublimely', 'figure', 'animation', 'family', 'resonance', 'third', 'sharp', 'denial', 'masterpiece', 'ryan', 'downtown', 'milestones', 'polson', 'asks', 'll', 'chance', 'sophisticated', 'giant', 'showtime', 'wanting', 'lack', 'alive', 'surreal', 'obsessive', 'forget', 'frei', 'twist', 'lends', 'provoked', 'collection', 'humour', 'graceless', 'bold', 'von', 'pause', 'broad', 'william', 'dv', 'hold', 'holocaust', 'sparkling', 'adventure', 'centered', 'especially', 'elegantly', 'james', 'racism', 'visual', 'our', 'oddly', 'wanes', 'desperately', 'regain', 'bowl', 'slice', 'although', 'glides', 'equivalent', 'madness', 'either', 'junk', 'quarter', 'brown', 'swiftly', 'why', 'feeling', 'ago', 'budget', 'super', 'maryam', 'mann', 'impressive', 'excited', 'possibly', 'same', 'allen', 'deserve']
# 1339
